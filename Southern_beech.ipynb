# %%
# !pip install pymupdf tabula-py PyPDF2 jpype1

# %%
import fitz
import tabula
import os
import glob
import pandas as pd
from IPython.display import Image, display

# %% [markdown]
# **Plio-Pleistocene environmental changes shape present day phylogeography of New Zealand's southern beeches (Nothofagaceae)**
#
# https://www.researchgate.net/publication/344681934_Plio-Pleistocene_environmental_changes_shape_present_day_phylogeography_of_New_Zealand's_southern_beeches_Nothofagaceae

# %%
display(Image('/content/images/19.jpeg'))

# %% [markdown]
# **DYNAMICS OF EVEN-AGED NOTHOFAGUS TRUNCATA AND
# N. FUSCA STANDS IN NORTH WESTLAND, NEW ZEALAND**
#
# https://www.scionresearch.com/__data/assets/pdf_file/0014/30614/NZJFS1711987SMALE12_28.pdf

# %%
display(Image('/content/volume-age.png'))

# %%
pdf_path = '/content/Boudewyn.pdf'

# %%
species_list = [2000, 1500, 1550, 4000]

for i in range(8, 21):
    table = dfs[i-1]
    table = table[table['species'].isin(species_list)]
    if not table.empty:
        dfs[i-1] = table
        display(table)
# Out:
#    jur  ecozone  species  volm  count        a        b        model  rmse
# 7   AB        9     1500   NaN    NaN  0.83507  0.90048     S(9-G10)   NaN
# 8   AB        9     1550   NaN    NaN  0.83507  0.90048     S(9-G10)   NaN
# 25  AB       10     1550   NaN    NaN  0.83507  0.90048     S(9-G10)   NaN
# 49  AB       14     1550   NaN    NaN  0.83507  0.90048     S(9-G10)   NaN
# 67  SK        6     1500   NaN    NaN  1.38776  0.82228  S(QC-6-G12)   NaN
#    jur  ecozone  species  volm  count        a        b        model  rmse
# 5   SK        9     1500   NaN    NaN  1.38776  0.82228  S(QC-6-G12)   NaN
# 48  MB        6     1500   NaN    NaN  1.38776  0.82228  S(QC-6-G12)   NaN
# 65  MB        9     1500   NaN    NaN  1.38776  0.82228  S(QC-6-G12)   NaN
#   jur  ecozone  species  volm  count        a        b        model  rmse
# 9  MB       10     1500   NaN    NaN  1.38776  0.82228  S(QC-6-G12)   NaN
#    jur  ecozone  species   volm  count        a        b      model  rmse
# ...
